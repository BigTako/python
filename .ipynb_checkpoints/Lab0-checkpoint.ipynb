# %%
import math


def is_sum_of_squares(c):
    
    if not isinstance(c, (int, float)):
        return 'Отримано нечислове значення'
    
    if c >= 0:
        for a in range(int(math.sqrt(c)) + 1):
            b = int(math.sqrt(c - a ** 2))

            if a ** 2 + b ** 2 == c:
                return f'{a}^2+{b}^2={c}'
        
    return f'Число {c} не можна представити квадратами двох цілих чисел'

# %%
print(is_sum_of_squares('str')) #Отримано нечислове значення
print(is_sum_of_squares(5.2)) #Число 5.2 не можна представити квадратами двох цілих чисел
print(is_sum_of_squares(-5)) #Число -5 не можна представити квадратами двох цілих чисел
print(is_sum_of_squares(5)) #1^2+2^2=5
print(is_sum_of_squares(8)) #2^2+2^2=8
print(is_sum_of_squares(11)) #Число 11 не можна представити квадратами двох цілих чисел
# Out:
# Отримано нечислове значення
# Число 5.2 не можна представити квадратами двох цілих чисел
# Число -5 не можна представити квадратами двох цілих чисел
# 1^2+2^2=5
# 2^2+2^2=8
# Число 11 не можна представити квадратами двох цілих чисел

# %%
# Норвегія

## Площа
Норвегія має площу в **385,207 км²**.

## Населення
Населення Норвегії становить приблизно *5,3 мільйона* людей.

## Державне устрій
Норвегія є <span style="color:blue">конституційною монархією</span>.

## Видатні персоналії
1. **Хенрік Ібсен** - видатний драматург.
2. **Едвард Мунк** - відомий художник.

## Пам'ятки культури та природи
- **Осло**:
    - Королівський палац
    - Національний театр
- **Берген**:
    - Брігген

![Осло](link_to_image)

[Джерело інформації](link_to_source)

<div style="border:1px solid black;padding:10px;">
    <h2>Таблиця населення</h2>
    <table>
        <tr>
            <th>Рік</th>
            <th>Населення</th>
        </tr>
        <tr>
            <td>2020</td>
            <td>5,367,580</td>
        </tr>
        <tr>
            <td>2021</td>
            <td>5,391,369</td>
        </tr>
    </table>
</div>

<svg width="22" height="16">
    <rect width="22" height="16" style="fill:red"/>
    <rect width="22" height="12" style="fill:white"/>
    <rect width="22" height="8" style="fill:blue"/>
</svg>
# Out:
#   Cell In[8], line 4
#     Норвегія має площу в **385,207 км²**.
#                                      ^
# SyntaxError: invalid character '²' (U+00B2)

# %%
# Норвегія

## Площа
Норвегія має площу в **385,207 км**.

## Населення
Населення Норвегії становить приблизно *5,3 мільйона* людей.

## Державне устрій
Норвегія є <span style="color:blue">конституційною монархією</span>.

## Видатні персоналії
1. **Хенрік Ібсен** - видатний драматург.
2. **Едвард Мунк** - відомий художник.

## Пам'ятки культури та природи
- **Осло**:
    - Королівський палац
    - Національний театр
- **Берген**:
    - Брігген

![Осло](link_to_image)

[Джерело інформації](link_to_source)

<div style="border:1px solid black;padding:10px;">
    <h2>Таблиця населення</h2>
    <table>
        <tr>
            <th>Рік</th>
            <th>Населення</th>
        </tr>
        <tr>
            <td>2020</td>
            <td>5,367,580</td>
        </tr>
        <tr>
            <td>2021</td>
            <td>5,391,369</td>
        </tr>
    </table>
</div>

<svg width="22" height="16">
    <rect width="22" height="16" style="fill:red"/>
    <rect width="22" height="12" style="fill:white"/>
    <rect width="22" height="8" style="fill:blue"/>
</svg>
# Out:
#   Cell In[9], line 4
#     Норвегія має площу в **385,207 км**.
#              ^
# SyntaxError: invalid syntax

# %%
print("# Норвегія

## Площа
Норвегія має площу в **385,207 км²**.

## Населення
Населення Норвегії становить приблизно *5,3 мільйона* людей.

## Державне устрій
Норвегія є <span style="color:blue">конституційною монархією</span>.

## Видатні персоналії
1. **Хенрік Ібсен** - видатний драматург.
2. **Едвард Мунк** - відомий художник.

## Пам'ятки культури та природи
- **Осло**:
    - Королівський палац
    - Національний театр
- **Берген**:
    - Брігген

![Осло](link_to_image)

[Джерело інформації](link_to_source)

<div style="border:1px solid black;padding:10px;">
    <h2>Таблиця населення</h2>
    <table>
        <tr>
            <th>Рік</th>
            <th>Населення</th>
        </tr>
        <tr>
            <td>2020</td>
            <td>5,367,580</td>
        </tr>
        <tr>
            <td>2021</td>
            <td>5,391,369</td>
        </tr>
    </table>
</div>

<svg width="22" height="16">
    <rect width="22" height="16" style="fill:red"/>
    <rect width="22" height="12" style="fill:white"/>
    <rect width="22" height="8" style="fill:blue"/>
</svg>")
